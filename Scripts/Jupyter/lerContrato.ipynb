# %%
import sys
import os
sys.path.insert(0, r'C:\Users\Matheus\Documents\Git\Pontte\automacaoRegistroAztronic\automacaoRegistroCCI\Scripts')
from lerPDF import lerPDF

# %%
files_dir = r"C:\Users\Matheus\Documents\Git\Pontte\automacaoRegistroAztronic\automacaoRegistroCCI\Contratos"
contratosFiles = [f for f in os.listdir(files_dir) if f.endswith(".pdf")]
contratosFiles
# Out:
# ['FI_Contrato_Juliana_Assinatura Digital.pdf',
#  'FI_Contrato_RenatoCandido_Assinatura Digital.pdf',
#  'FI_Contrato_Romilton_Assinatura Digital-Manifesto.pdf',
#  'HE_Contrato_Agapee_Assinatura Digital_VFinal.pdf',
#  'HE_Contrato_Agostinho_Assinatura Digital_VFinal.pdf',
#  'HE_Contrato_Conrado_Assinatura Digital_VFinal - Conrado.pdf',
#  'HE_Contrato_Margareide_Assinatura Digital_VFinal.pdf',
#  'HE_Contrato_Oliboni _Assinatura Digital_VFinal.pdf',
#  'HE_Contrato_PatriciaMarcondes_Assinatura Digital_VFinal.pdf',
#  'HE_Contrato_Vanessa_VFinal_PDFA.pdf']

# %%
for contrato in contratosFiles:
    path = os.path.join(files_dir, contrato)
    print(path)
    texto = lerPDF(path, 2)
    print(texto)
# Out:
# C:\Users\Matheus\Documents\Git\Pontte\automacaoRegistroAztronic\automacaoRegistroCCI\Contratos\FI_Contrato_Juliana_Assinatura Digital.pdf
# ...
